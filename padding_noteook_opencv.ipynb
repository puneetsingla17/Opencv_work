# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread('roi.jpg')

# %%
img.shape
# Out:
# (280, 450, 3)

# %%
replicate=cv2.copyMakeBorder(img,50,50,50,50,cv2.BORDER_REPLICATE)

# %%
plt.imshow(img)

# %%
plt.imshow(replicate)

# %%
replicate.shape
# Out:
# (380, 550, 3)

# %%
#4 values after img are padding values on top below left and right of image
